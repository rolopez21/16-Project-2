# %%
from math import sqrt
from numpy import concatenate
from matplotlib import pyplot
from pandas import read_csv
from pandas import DataFrame
from pandas import concat
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
# Out:
# Using TensorFlow backend.

# %%
from pandas import read_csv
from matplotlib import pyplot
# load dataset
dataset = read_csv('../data/cleandata/DataMulti.csv', header=0, index_col=0)
values = dataset.values
# specify columns to plot
groups = [0, 1, 2, 3, 5, 6, 7]
i = 1
# to plot each column
pyplot.figure()
for group in groups:
    pyplot.subplot(len(groups), 1, i)
    pyplot.plot(values[:, group])
    pyplot.title(dataset.columns[group], y=0.5, loc='right')
    i += 1
pyplot.show()

# %%
#  series to supervised learning
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = DataFrame(data)
    cols, names = list(), list()
# input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
        else:
            names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
    # put it all together
    agg = concat(cols, axis=1)
    agg.columns = names
    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg
 
# load dataset
dataset = read_csv('../data/cleandata/DataMulti.csv', header=0, index_col=0)
values = dataset.values
# integer encode direction
encoder = LabelEncoder()
values[:,4] = encoder.fit_transform(values[:,4])
# ensure all data is float
values = values.astype('float32')
# normalize features
scaler = MinMaxScaler(feature_range=(0, 1))
scaled = scaler.fit_transform(values)
# frame as supervised learning
reframed = series_to_supervised(scaled, 1, 1)
# drop columns we don't want to predict
reframed.drop(reframed.columns[[9,10,11,12,13,14,15]], axis=1, inplace=True)
print(reframed.head())



# convert series to supervised learning
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = DataFrame(data)
    cols, names = list(), list()
    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
        else:
            names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
    # put it all together
    agg = concat(cols, axis=1)
    agg.columns = names
    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg
 
# load dataset
dataset = read_csv('../data/cleandata/DataMulti.csv', header=0, index_col=0)
values = dataset.values
# integer encode direction
encoder = LabelEncoder()
values[:,4] = encoder.fit_transform(values[:,4])
# ensure all data is float
values = values.astype('float32')
# normalize features
scaler = MinMaxScaler(feature_range=(0, 1))
scaled = scaler.fit_transform(values)
# frame as supervised learning
reframed = series_to_supervised(scaled, 1, 1)
# drop columns we don't want to predict
reframed.drop(reframed.columns[[9,10,11,12,13,14,15]], axis=1, inplace=True)
print(reframed.head())
# Out:
#    var1(t-1)  var2(t-1)  var3(t-1)  var4(t-1)  var5(t-1)  var6(t-1)  \
# 1   0.071272   0.331464   0.964773   0.291054   0.344710   0.307162
# 2   0.056448   0.338253   0.961932   0.296118   0.337884   0.315554
# 3   0.052233   0.278335   0.955682   0.244032   0.223549   0.254383
# 4   0.054559   0.244687   0.958523   0.212684   0.184300   0.229952
# 5   0.062552   0.286895   0.958523   0.247890   0.262799   0.268184
#
#    var7(t-1)  var8(t-1)   var1(t)
# 1   0.251506   0.003890  0.056448
# 2   0.263069   0.014263  0.052233
# 3   0.247410   0.004898  0.054559
# 4   0.213924   0.003025  0.062552
# 5   0.202361   0.012966  0.054413
#    var1(t-1)  var2(t-1)  var3(t-1)  var4(t-1)  var5(t-1)  var6(t-1)  \
# 1   0.071272   0.331464   0.964773   0.291054   0.344710   0.307162
# 2   0.056448   0.338253   0.961932   0.296118   0.337884   0.315554
# 3   0.052233   0.278335   0.955682   0.244032   0.223549   0.254383
# 4   0.054559   0.244687   0.958523   0.212684   0.184300   0.229952
# 5   0.062552   0.286895   0.958523   0.247890   0.262799   0.268184
#
#    var7(t-1)  var8(t-1)   var1(t)
# 1   0.251506   0.003890  0.056448
# 2   0.263069   0.014263  0.052233
# 3   0.247410   0.004898  0.054559
# 4   0.213924   0.003025  0.062552
# 5   0.202361   0.012966  0.054413

# %%
 
# split into train and test sets
values = reframed.values
n_train_days = 484
train = values[:n_train_days, :]
test = values[n_train_days:, :]
# split into input and outputs
train_X, train_y = train[:, :-1], train[:, -1]
test_X, test_y = test[:, :-1], test[:, -1]
# reshape input to be 3D [samples, timesteps, features]
train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (484, 1, 8) (484,) (120, 1, 8) (120,)

# %%
# design network
model = Sequential()
model.add(LSTM(50, input_shape=(train_X.shape[1], train_X.shape[2])))
model.add(Dense(1))
model.compile(loss='mae', optimizer='adam')
# fit network
history = model.fit(train_X, train_y, epochs=50, batch_size=72, validation_data=(test_X, test_y), verbose=2, shuffle=False)
# plot history
pyplot.plot(history.history['loss'], label='train')
pyplot.plot(history.history['val_loss'], label='test')
pyplot.legend()
pyplot.show()
# Out:
# Train on 484 samples, validate on 120 samples
# Epoch 1/50
#  - 3s - loss: 0.3785 - val_loss: 0.3142
# Epoch 2/50
#  - 0s - loss: 0.2994 - val_loss: 0.2227
# Epoch 3/50
#  - 0s - loss: 0.2552 - val_loss: 0.1499
# Epoch 4/50
#  - 0s - loss: 0.2211 - val_loss: 0.0887
# Epoch 5/50
#  - 0s - loss: 0.1902 - val_loss: 0.0469
# Epoch 6/50
#  - 0s - loss: 0.1691 - val_loss: 0.0423
# Epoch 7/50
#  - 0s - loss: 0.1561 - val_loss: 0.0692
# Epoch 8/50
#  - 0s - loss: 0.1462 - val_loss: 0.0887
# Epoch 9/50
#  - 0s - loss: 0.1378 - val_loss: 0.0953
# Epoch 10/50
#  - 0s - loss: 0.1287 - val_loss: 0.0936
# Epoch 11/50
#  - 0s - loss: 0.1185 - val_loss: 0.0897
# Epoch 12/50
#  - 0s - loss: 0.1080 - val_loss: 0.0877
# Epoch 13/50
#  - 0s - loss: 0.0975 - val_loss: 0.0876
# Epoch 14/50
#  - 0s - loss: 0.0870 - val_loss: 0.0892
# Epoch 15/50
#  - 0s - loss: 0.0766 - val_loss: 0.0930
# Epoch 16/50
#  - 0s - loss: 0.0679 - val_loss: 0.0970
# Epoch 17/50
#  - 0s - loss: 0.0612 - val_loss: 0.0996
# Epoch 18/50
#  - 0s - loss: 0.0561 - val_loss: 0.1010
# Epoch 19/50
#  - 0s - loss: 0.0524 - val_loss: 0.1021
# Epoch 20/50
#  - 0s - loss: 0.0498 - val_loss: 0.1033
# Epoch 21/50
#  - 0s - loss: 0.0482 - val_loss: 0.1040
# Epoch 22/50
#  - 0s - loss: 0.0472 - val_loss: 0.1042
# Epoch 23/50
#  - 0s - loss: 0.0467 - val_loss: 0.1040
# Epoch 24/50
#  - 0s - loss: 0.0463 - val_loss: 0.1032
# Epoch 25/50
#  - 0s - loss: 0.0461 - val_loss: 0.1032
# Epoch 26/50
#  - 0s - loss: 0.0457 - val_loss: 0.1035
# Epoch 27/50
#  - 0s - loss: 0.0454 - val_loss: 0.1029
# Epoch 28/50
#  - 0s - loss: 0.0452 - val_loss: 0.1027
# Epoch 29/50
#  - 0s - loss: 0.0449 - val_loss: 0.1030
# Epoch 30/50
#  - 0s - loss: 0.0446 - val_loss: 0.1028
# Epoch 31/50
#  - 0s - loss: 0.0443 - val_loss: 0.1023
# Epoch 32/50
#  - 0s - loss: 0.0440 - val_loss: 0.1017
# Epoch 33/50
#  - 0s - loss: 0.0438 - val_loss: 0.1016
# Epoch 34/50
#  - 0s - loss: 0.0435 - val_loss: 0.1016
# Epoch 35/50
#  - 0s - loss: 0.0432 - val_loss: 0.1017
# Epoch 36/50
#  - 0s - loss: 0.0428 - val_loss: 0.1014
# Epoch 37/50
#  - 0s - loss: 0.0426 - val_loss: 0.1012
# Epoch 38/50
#  - 0s - loss: 0.0423 - val_loss: 0.1011
# Epoch 39/50
#  - 0s - loss: 0.0419 - val_loss: 0.1002
# Epoch 40/50
#  - 0s - loss: 0.0418 - val_loss: 0.0994
# Epoch 41/50
#  - 0s - loss: 0.0415 - val_loss: 0.1004
# Epoch 42/50
#  - 0s - loss: 0.0410 - val_loss: 0.1002
# Epoch 43/50
#  - 0s - loss: 0.0408 - val_loss: 0.0991
# Epoch 44/50
#  - 0s - loss: 0.0406 - val_loss: 0.0997
# Epoch 45/50
#  - 0s - loss: 0.0401 - val_loss: 0.0995
# Epoch 46/50
#  - 0s - loss: 0.0399 - val_loss: 0.0986
# Epoch 47/50
#  - 0s - loss: 0.0396 - val_loss: 0.0987
# Epoch 48/50
#  - 0s - loss: 0.0393 - val_loss: 0.0985
# Epoch 49/50
#  - 0s - loss: 0.0390 - val_loss: 0.0980
# Epoch 50/50
#  - 0s - loss: 0.0388 - val_loss: 0.0981

# %%
# make a prediction
yhat = model.predict(test_X)
test_X = test_X.reshape((test_X.shape[0], test_X.shape[2]))
# invert scaling for forecast
inv_yhat = concatenate((yhat, test_X[:, 1:]), axis=1)
inv_yhat = scaler.inverse_transform(inv_yhat)
inv_yhat = inv_yhat[:,0]
# invert scaling for actual
test_y = test_y.reshape((len(test_y), 1))
inv_y = concatenate((test_y, test_X[:, 1:]), axis=1)
inv_y = scaler.inverse_transform(inv_y)
inv_y = inv_y[:,0]
# calculate RMSE
rmse = sqrt(mean_squared_error(inv_y, inv_yhat))
print('Test RMSE: %.3f' % rmse)
# Out:
# Test RMSE: 7.048

# %%
# load dataset
dataset = read_csv('DataMulti.csv', header=0, index_col=0)
values = dataset.values
# integer encode direction
encoder = LabelEncoder()
values[:,4] = encoder.fit_transform(values[:,4])
# ensure all data is float
values = values.astype('float32')
# normalize features
scaler = MinMaxScaler(feature_range=(0, 1))
scaled = scaler.fit_transform(values)
# specify the number of lag days
n_days = 1
n_features = 8
# frame as supervised learning
reframed = series_to_supervised(scaled, n_days, 1)
print(reframed.shape)
 
# split into train and test sets
values = reframed.values
n_train_days = 484
train = values[:n_train_days, :]
test = values[n_train_days:, :]
# split into input and outputs
n_obs = n_days * n_features
train_X, train_y = train[:, :n_obs], train[:, -n_features]
test_X, test_y = test[:, :n_obs], test[:, -n_features]
print(train_X.shape, len(train_X), train_y.shape)
# reshape input to be 3D [samples, timesteps, features]
train_X = train_X.reshape((train_X.shape[0], n_days, n_features))
test_X = test_X.reshape((test_X.shape[0], n_days, n_features))
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
 
# design network
model = Sequential()
model.add(LSTM(50, input_shape=(train_X.shape[1], train_X.shape[2])))
model.add(Dense(1))
model.compile(loss='mae', optimizer='adam')
# fit network
history = model.fit(train_X, train_y, epochs=50, batch_size=72, validation_data=(test_X, test_y), verbose=2, shuffle=False)
# plot history
pyplot.plot(history.history['loss'], label='train')
pyplot.plot(history.history['val_loss'], label='test')
pyplot.legend()
pyplot.show()
 
# make a prediction
yhat = model.predict(test_X)
test_X = test_X.reshape((test_X.shape[0], n_days*n_features))
# invert scaling for forecast
inv_yhat = concatenate((yhat, test_X[:, -7:]), axis=1)
inv_yhat = scaler.inverse_transform(inv_yhat)
inv_yhat = inv_yhat[:,0]
# invert scaling for actual
test_y = test_y.reshape((len(test_y), 1))
inv_y = concatenate((test_y, test_X[:, -7:]), axis=1)
inv_y = scaler.inverse_transform(inv_y)
inv_y = inv_y[:,0]
# calculate RMSE
rmse = sqrt(mean_squared_error(inv_y, inv_yhat))
print('Test RMSE: %.3f' % rmse)
# Out:
# (604, 16)
# (484, 8) 484 (484,)
# (484, 1, 8) (484,) (120, 1, 8) (120,)
# Train on 484 samples, validate on 120 samples
# Epoch 1/50
#  - 1s - loss: 0.3097 - val_loss: 0.2514
# Epoch 2/50
#  - 0s - loss: 0.2635 - val_loss: 0.1826
# Epoch 3/50
#  - 0s - loss: 0.2274 - val_loss: 0.1195
# Epoch 4/50
#  - 0s - loss: 0.1939 - val_loss: 0.0668
# Epoch 5/50
#  - 0s - loss: 0.1649 - val_loss: 0.0430
# Epoch 6/50
#  - 0s - loss: 0.1478 - val_loss: 0.0615
# Epoch 7/50
#  - 0s - loss: 0.1370 - val_loss: 0.0833
# Epoch 8/50
#  - 0s - loss: 0.1293 - val_loss: 0.0927
# Epoch 9/50
#  - 0s - loss: 0.1209 - val_loss: 0.0926
# Epoch 10/50
#  - 0s - loss: 0.1110 - val_loss: 0.0892
# Epoch 11/50
#  - 0s - loss: 0.1004 - val_loss: 0.0876
# Epoch 12/50
#  - 0s - loss: 0.0897 - val_loss: 0.0887
# Epoch 13/50
#  - 0s - loss: 0.0795 - val_loss: 0.0921
# Epoch 14/50
#  - 0s - loss: 0.0702 - val_loss: 0.0970
# Epoch 15/50
#  - 0s - loss: 0.0625 - val_loss: 0.1009
# Epoch 16/50
#  - 0s - loss: 0.0570 - val_loss: 0.1026
# Epoch 17/50
#  - 0s - loss: 0.0527 - val_loss: 0.1036
# Epoch 18/50
#  - 0s - loss: 0.0498 - val_loss: 0.1045
# Epoch 19/50
#  - 0s - loss: 0.0479 - val_loss: 0.1063
# Epoch 20/50
#  - 0s - loss: 0.0467 - val_loss: 0.1077
# Epoch 21/50
#  - 0s - loss: 0.0459 - val_loss: 0.1080
# Epoch 22/50
#  - 0s - loss: 0.0455 - val_loss: 0.1079
# Epoch 23/50
#  - 0s - loss: 0.0451 - val_loss: 0.1068
# Epoch 24/50
#  - 0s - loss: 0.0450 - val_loss: 0.1061
# Epoch 25/50
#  - 0s - loss: 0.0447 - val_loss: 0.1066
# Epoch 26/50
#  - 0s - loss: 0.0442 - val_loss: 0.1066
# Epoch 27/50
#  - 0s - loss: 0.0440 - val_loss: 0.1059
# Epoch 28/50
#  - 0s - loss: 0.0437 - val_loss: 0.1056
# Epoch 29/50
#  - 0s - loss: 0.0434 - val_loss: 0.1053
# Epoch 30/50
#  - 0s - loss: 0.0431 - val_loss: 0.1048
# Epoch 31/50
#  - 0s - loss: 0.0428 - val_loss: 0.1044
# Epoch 32/50
#  - 0s - loss: 0.0425 - val_loss: 0.1040
# Epoch 33/50
#  - 0s - loss: 0.0422 - val_loss: 0.1037
# Epoch 34/50
#  - 0s - loss: 0.0419 - val_loss: 0.1036
# Epoch 35/50
#  - 0s - loss: 0.0415 - val_loss: 0.1034
# Epoch 36/50
#  - 0s - loss: 0.0413 - val_loss: 0.1028
# Epoch 37/50
#  - 0s - loss: 0.0410 - val_loss: 0.1027
# Epoch 38/50
#  - 0s - loss: 0.0407 - val_loss: 0.1023
# Epoch 39/50
#  - 0s - loss: 0.0404 - val_loss: 0.1020
# Epoch 40/50
#  - 0s - loss: 0.0401 - val_loss: 0.1021
# Epoch 41/50
#  - 0s - loss: 0.0398 - val_loss: 0.1018
# Epoch 42/50
#  - 0s - loss: 0.0395 - val_loss: 0.1014
# Epoch 43/50
#  - 0s - loss: 0.0392 - val_loss: 0.1012
# Epoch 44/50
#  - 0s - loss: 0.0389 - val_loss: 0.1010
# Epoch 45/50
#  - 0s - loss: 0.0386 - val_loss: 0.1003
# Epoch 46/50
#  - 0s - loss: 0.0384 - val_loss: 0.1003
# Epoch 47/50
#  - 0s - loss: 0.0380 - val_loss: 0.0996
# Epoch 48/50
#  - 0s - loss: 0.0377 - val_loss: 0.0988
# Epoch 49/50
#  - 0s - loss: 0.0375 - val_loss: 0.0985
# Epoch 50/50
#  - 0s - loss: 0.0371 - val_loss: 0.0980
# Test RMSE: 6.978
